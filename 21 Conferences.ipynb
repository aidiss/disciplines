# %% [markdown]
# Conferences are one of more interesting phenomenon to researchers in field of studies of sciences and technology. Scholars meet in conferences they exchange ideas, make presentations, establish contacts and partnerships. Who know what else is happening.
#
# Here we will analyze some conference and how to get data about them.

# %%
from disciplines.data import conferences

# %%
import inspect
inspect.getmembers(conferences, inspect.isfunction)
# Out:
# [('conference_alerts',
#   <function disciplines.data.conferences.conference_alerts>),
#  ('wikicfp', <function disciplines.data.conferences.wikicfp>)]

# %% [markdown]
# # STS conferences

# %% [markdown]
# At some moment we would like to know about where information about conference is comming from. Currently we can do that by using conferences.listings command.

# %%
conferences.listings
# Out:
# ['grc', 'faseb', 'all_conferences', 'conference_alerts', 'wikicfp']

# %% [markdown]
# As you can see currently we have 5 sources: 'grc', 'faseb', 'all_conferences', 'conference_alerts', 'wikicfp'. We can use them to get data about conferences.
#
# implement! data source has to be commented regarding how information cna be obtained. Do they provide xmls? rss feeds? anything else?

# %%
#as you can see, currently this is not well structured.
for x in range(len(conferences.thedict)):
    print conferences.thedict[x].keys()
# Out:
# ['things available', 'name', 'disciplines', 'url', "'Possibility to show only new meeting's", 'Categories']
# ['xml', 'name', 'url', 'xml_url', 'url1', 'structure']
# ['url', 'name', 'structure', 'Categories']

# %% [markdown]
# ## GRC and conference listings

# %% [markdown]
# There are some others things that we are aware about different conference databases. These databases cattegorize research into different fields.

# %%
conferences.thedict[0]['Categories']
# Out:
# ['biophisics',
#  'astrophysics',
#  'atomic physics',
#  'biological chemistry',
#  'computation',
#  'condesned matter phsyics and nanostructures',
#  'developmental systems',
#  'environment and evolution',
#  'inorganic chemistry',
#  'instrumentation',
#  'materials',
#  'microbes and viruses',
#  'molecular cell biology',
#  'neurobiology',
#  'optical physics',
#  'organic chemistry',
#  'other',
#  'pathology',
#  'pharmacology and therapeutics',
#  'science education',
#  'science policy']

# %% [markdown]
# ## FASEB and how to use links

# %% [markdown]
# Lets look into other FASEB database, what is the structure?

# %%
conferences.thedict[1]['name'], conferences.thedict[1]['structure']
# Out:
# ('faseb', ['Title', 'Link', 'Description', 'Startdate'])

# %% [markdown]
# The information above was manually added by looking at the website.

# %% [markdown]
# We can see whether xml is available and lookin into urls by using xml and xml_url keys.

# %%
conferences.thedict[1]['xml'], conferences.thedict[1]['xml_url']
# Out:
# (True, 'http://www.faseb.org/ListXML.aspx?Type=rss&Content=EventsSRC')

# %% [markdown]
# Urls can be accessed by using urls

# %%
conferences.thedict[1]['url'], conferences.thedict[1]['url1']
# Out:
# ('http://www.faseb.org/science-research-conferences.aspx',
#  'https://secure.faseb.org/FASEB/meetings/summrconf/selecttopic.aspx')

# %% [markdown]
# # Conference alerts

# %%
conference_alerts = conferences.conference_alerts()
[x.keys() for x in conference_alerts]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e03c0c8b19da> in <module>()
# ----> 1 conference_alerts = conferences.conference_alerts()
#       2 [x.keys() for x in conference_alerts]
#
# AttributeError: 'ResultSet' object has no attribute 'conference_alerts'

# %% [markdown]
# We can look more into the classifications, lets look more into interdisciplinary.

# %%
conference_alerts[1].values()
# Out:
# [['Children and Youth',
#   'Communications and Media',
#   'Complex Systems',
#   'Conflict resolution',
#   'Creativity\t',
#   'Culture',
#   'Disaster Management',
#   'Discourse',
#   'Film studies',
#   'GLBT Studies',
#   'Gender studies',
#   'Globalization',
#   'HIV/AIDS',
#   'Human Rights',
#   'Identity',
#   'Leadership',
#   'Memory',
#   'Poverty',
#   'Public Policy',
#   'Security',
#   'Sexuality and eroticism',
#   'Spirituality',
#   'Sport science',
#   'Sustainable development',
#   'Tourism',
#   'Urban studies',
#   'Violence',
#   "Women's studies"]]

# %%
import requests

url = 'http://www.conferencealerts.com/search.php?page=1&ipp=All&searchTerm=&x=1&y=14'
r = requests.get(url)
r.text
# Out:
# u'\n<!DOCTYPE html>\n<html>\n\n<head>\n<link rel="stylesheet" type="text/css" href="site.css?ver=1600" media="screen" />\n<link rel="icon" type="image/png" href="images/favicon.png" />\n<title>Conference Alerts - Search</title>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n<meta name="description" content="Search the Conference Alerts database for events." />\n<meta name="keywords" content="conference, conferences, academic conferences, conference publicity, conference promotion,\neducation conferences, psychology conferences, sociology conferences, conference database, conference service" />\n<script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js"></script>\n<script type="text/javascript" src="JavaMd5.js"></script>\n<script type="text/javascript" src="Utf8_Encode.js"></script>\n<script type="text/javascript" src="LogInOut.js"></script>\n<script type="text/javascript" src="ca.js"></script>\n<script type="text/javascript" src="niftycube.js"></script>\n<script type="text/javascript" src="jquery.autocomplete-min.js"></script>\n<script type="text/javascript">\n$(document).ready(loadNifty);\n</script>\n<script type="text/javascript">\n\n    var _gaq = _gaq || [];\n    _gaq.push([\'_setAccount\', \'UA-39230874-1\']);\n    _gaq.push([\'_trackPageview\']);\n\n    (function() {\n        var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n        ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n        var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n    })();\n\n</script>\n</head>\n\n<body>\n\n<div id="homeLink"><a href="index" title="Home" id="homeLink">Home</a></div>\n\n<div id="trademark">&trade;</div><a href="index"><img style="position: absolute; cursor: pointer; border-style: none; left: 19px;" src="images/bannerg.jpg?ver=1500" align="left" title="Home" /></a>\n\n<div id="registerDiv"></div>\n\n<div id="searchDiv">\n            <form method="get" action="search">\n            <table id="searchBoxTable">\n                <tr>\n                    <td rowspan="2">\n                        <a href="faq">\n                            <div id="upgradeButton" class="upgradeButton textCenter">\n                                How to use our site\n                            </div>\n                        </a>\n                    </td>\n                    <td class="spacer20w"></td>\n                    <td><input id="searchText" type="text" name="searchTerm" value="Search" onfocus="if(this.value==this.defaultValue)this.value=\'\';" onblur="if(this.value==\'\')this.value=this.defaultValue;" /></td>\n                    <td>&nbsp;&nbsp;&nbsp;<input id="searchImage" title="Search" type="image" src="images/search_small.png" /></td>\n                </tr>\n                <tr>\n                    <td></td>\n                    <td align="center"><span id="smallText"><a href="advanced-search" onclick="loadSearchDatePickers()">(Advanced search)</a></span></td>\n                </tr>\n            </table>\n            </form>\n        </div>\n\n<div id="loginDivContainer">\n                <form action="javascript:login();" id="login_form">\n                <table id="logInTable">\n                    <tr>\n                        <td id="tablePad">\n                            <span id="loginText">Log in&nbsp;&nbsp;&nbsp;</span>\n                        </td>\n                        <td id="tablePad">\n                            <p>\n                                <label for="userNameTextBox">Username</label>\n                                <input id="userNameTextBox" type="text" name="username" value="" />\n                            </p>\n                        </td>\n                        <td id="tablePad">\n                            <p>\n                                <label for="passwordTextBox">Passwo ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text)
conferences = soup.findAll('table', {'id':'searchResultTable'})[0].findAll('a')

# %%
len(conferences)
# Out:
# 3409

# %%
conferences[0:5]
# Out:
# [<a href="show-event?id=134019" style="font-size: 120%; font-weight: bold;">2014 2nd International Conference on Renewable Energy and Environment (ICREE 2014)</a>,
#  <a href="show-event?id=140376">(SCOPUS Indexed) The 2nd International Conference on Management and Technology in Knowledge, Service, Tourism &amp; Hospitality 2014 (SERVE 2014)</a>,
#  <a href="show-event?id=128488">International Conference on Womenâs Studies</a>,
#  <a href="show-event?id=134238">International Conference on Research Methods in Management and Social Sciences</a>,
#  <a href="show-event?id=140516">Global Chinese Financial Forum (GCFF) Toronto</a>]

# %% [markdown]
# # HNET

# %%
https://www.h-net.org/announce/show.cgi?ID=123476

# %% [markdown]
# ## Future..

# %% [markdown]
# - The entries discussed here should be put into a system. [link to issue]
# - Automatic identification of appearing databases. [link to issue]
# - Retrieval of information about conferences. [link to issue]
